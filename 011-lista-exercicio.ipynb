# %% [markdown]
# ### Lista 2 - EXERCÍCIOS PYTHON

# %% [markdown]
# 01. Uma escola está montando um cadastro simples de alunos para uma atividade
# interna. O sistema deve solicitar ao usuário o nome de cinco alunos e
# armazenar todos em uma única lista. Ao final do cadastro, o programa deve
# exibir todos os nomes cadastrados.

# %%
delta=input("qual seu nome")
rota=input("qual seu nome")
fuga=input("qual seu nome")
frota=input("qual seu nome")
total=input("qual seu nome")
lista=[total,frota,fuga,delta,rota]
print(lista)
# Out:
# ['miguel', 'Joaquim', 'Carlo', 'Jose', 'Maria']

# %% [markdown]
# 02. Um professor registrou algumas notas em uma lista numérica. Ele precisa saber quais notas ficaram acima de 10 para uma análise específica. Desenvolva um programa que, a partir de uma lista de números já existente, gere uma nova
# lista contendo apenas os valores maiores que 10.

# %%
lista=[2,4,19,13,15,12,17,20,23,21]
maiorque10=[]
for x in lista:
    if x >10 :
        maiorque10.append(x)
print(maiorque10)
# Out:
# [19, 13, 15, 12, 17, 20, 23, 21]

# %% [markdown]
# 3. Durante um experimento, sete valores inteiros foram coletados e precisam ser
# analisados. Crie um programa que leia esses valores, armazene em uma lista e
# determine qual foi o maior valor, o menor valor e a soma total dos números
# informados, sem utilizar funções prontas da linguagem.

# %%
valores = []
valores.append(int(input("Digite o 1°valor:")))
valores.append(int(input("Digite o 2°valor:")))
valores.append(int(input("Digite o 3°valor:")))
valores.append(int(input("Digite o 4°valor:")))
valores.append(int(input("Digite o 5°valor:")))
valores.append(int(input("Digite o 6°valor:")))
valores.append(int(input("Digite o 7°valor:")))

maior = valores[0]
menor = valores[0]

soma= ( 
      valores[0] + valores[1] + valores[2] + valores[3] + valores[4] + valores[5] + valores[6]  )

if valores[1] > maior:
    maior = valores[1]
if valores[2] > maior:
    maior = valores[2]
if valores[3] > maior:
    maior = valores[3]
if valores[4] > maior:
    maior = valores[4]
if valores[5] > maior:
    maior = valores[5] 
if valores[6] > maior:
    maior = valores[6]  

if valores[1] < menor:
    menor = valores[1] 
if valores[2] < menor:
    menor = valores[2]
if valores[3] < menor:
    menor = valores[3]  
if valores[4] < menor:
    menor = valores[4]
if valores[5] < menor:
    menor = valores[5]
if valores[6] < menor:
    menor = valores[6]
    
print("Maior valor:", maior)  
print("Menor valor:",menor)
# Out:
# Maior valor: 88
# Menor valor: 1

# %% [markdown]
# 04. Um sistema armazena 10 palavras digitadas pelo usuários em uma lista. Para uma análise linguística simples, deseja-se saber quantas dessas palavras possuem
# mais de cinco letras. Desenvolva um programa que percorra a lista e faça essa
# contagem.

# %%
lista = []

for repeticao in range(10):
    palavra_digitada = input(f"Digite {repeticao+1}ª palavra: ")
    lista.append(palavra_digitada)

print(lista)
# ['Pimenta', 'Café', 'Arroz', 'Feijão', 'Açucar', 'Carne', 'Cheiro Verde', 'Flocão', 'Tomate', 'Lasanha']

for temp in lista:
    if len(temp) > 5:
        print(f"{temp} (tem {len(temp)} letras)")
# Out:
# ['arroz', 'casa', 'macarrão', 'leite', 'agua', 'papel', 'jogos', 'senac', 'aula', 'portugues']
# macarrão (tem 8 letras)
# portugues (tem 9 letras)

# %%
lista = []
nova_lista = []

for repeticao in range(10):
    lista.append(input(f"Digite {repeticao+1}ª palavra: "))

for temp in lista:
    if len(temp) > 5: nova_lista.append(temp)

print(f"Lista completa: {lista}")
print(*nova_lista, sep=", ")
# Out:
# Lista completa: ['', '', '', '', '', '', '', '', '', '']

# %% [markdown]
# 05. Uma aplicação precisa organizar números informados pelo usuário de acordo com sua paridade. O programa deve solicitar dez números inteiros, armazená-los em uma lista principal e, posteriormente, separá-los em duas novas listas uma contendo apenas números pares e outra contendo apenas números ímpares. Ao final, todas as listas devem ser exibidas.

# %%
nume = []
impares = []
pares = []
for i in range(6):
    n = int(input("digite um numero"))
    nume.append(n)
    if n % 2== 0: 
        pares.append(n)
    else:
        impares.append(n)
    
print(*nume)
print(pares)
print(impares)

# %% [markdown]
# 06. Um site esportivo permite que o usuário informe nomes de esportes que pratica. Os dados devem ser armazenados até que o usuário digite a palavra “fimˮ. Após o encerramento da entrada, o sistema deve mostrar quantos esportes foram cadastrados e exibi-los em ordem alfabética.

# %%
lista = []
while True:
    antonio = input("informe a modalidade")
    if antonio == "fim":
        break
    lista.append(antonio)
lista.sort()
print(lista)
# Out:
# ['box', 'futbol', 'volei']

# %% [markdown]
# 07. Um sistema financeiro armazena valores de transações em uma lista. Para uma
# simulação, é necessário gerar uma nova lista onde cada valor corresponda ao
# dobro do valor original. Desenvolva um programa que realize essa
# transformação sem alterar a lista inicial.

# %%
dinheiro=[3,7,8,9,10,12,13,14]
dobro=[]

for i in dinheiro:
    dobro.append(i*2)
print(dobro)
# Out:
# [6, 14, 16, 18, 20, 24, 26, 28]

# %% [markdown]
# 08. Um laboratório registrou oito medições numéricas. Após armazenar esses valores em uma lista, o sistema deve calcular a média aritmética e identificar
# quais medições ficaram acima dessa média, exibindo apenas esses valores.

# %%
listas = []
for n in range(8):
    medicao = float(input("Digite as medições:\n"))
    listas.append(medicao)
for lista in listas:
    if lista>(sum(listas)/len(listas)):
        print(f"A média é {sum(listas)/len(listas)} e essas medições estão acima da média: {lista}")
# Out:
# Essas medições estão acima da média: 15.0
# Essas medições estão acima da média: 20.0

# %% [markdown]
# 09. Uma aplicação recebe uma lista com letras repetidas. Para fins estatísticos, é necessário contar quantas vezes cada letra aparece na lista. Desenvolva um programa que faça essa contagem sem utilizar métodos prontos de contagem da linguagem.

# %%
letras = ["a","b","a","c","b","a","d","c"]
letras_usadas = []

for letra_atual in letras:
    if letra_atual not in letras_usadas:
        total = 0
        
        for letras_lista in letras:
            if letras_lista == letra_atual:
               total = total + 1
            
        print(letra_atual, "aparece", total ,"vezes") 
        letras_usadas.append(letra_atual)
# Out:
# a aparece 3 vezes
# b aparece 2 vezes
# c aparece 2 vezes
# d aparece 1 vezes

# %% [markdown]
# 10. Durante um processamento de dados, cinco números foram armazenados na ordem em que foram informados. O sistema deve exibir essa lista exatamente como foi digitada e, em seguida, mostrar os mesmos valores em ordem inversa, sem utilizar funções prontas de inversão.

# %%
lista_normal=[10,20,30,40,50]
lista_reversa=[]

for i in range(len(lista_normal)-1,-1,-1):
    lista_reversa.append(lista_normal[i])

print (*lista_normal)
print (*lista_reversa)
# Out:
# 10 20 30 40 50
# 50 40 30 20

# %% [markdown]
# 11. Um professor deseja armazenar os nomes dos alunos e suas respectivas notas
# finais. Crie um programa que leia essas informações, utilizando duas listas distintas, e depois exiba apenas o nome dos alunos que alcançaram média maior ou igual a 7.

# %%
alunos = []
notas = []

quant = int(input("quantos alunos? "))

for i in range(quant):
    nome = input(f"nome do {i+1}º:")
    nota = float(input("nota: "))
    
    alunos.append(nome)
    notas.append(nota)

for i in range(quant):
    if notas[i] >= 7:
        print(alunos[i])
# Out:
# rayran
# jose

# %% [markdown]
# 12. Um sistema recebe dez números inteiros, mas não deve armazenar valores
# repetidos. Desenvolva um programa que leia os números, armazene-os em
# uma lista e gere uma nova lista contendo apenas valores únicos.

# %%
list_0 = []
list_1 = []

while True: 
    num0 = int(input(""))
    if num0 == 0: break
    list_0.append(num0)

for L in list_0:
    if L not in list_1:
        list_1.append(L)
        
print(list_0)
print(list_1)
# Out:
# [4, 5, 5, 6, 4, 1, 2]
# [4, 5, 6, 1, 2]

# %% [markdown]
# 13. Um instituto meteorológico registra a temperatura média de cada mês do ano.
# Crie um programa que armazene essas temperaturas em uma lista, calcule a
# média anual e identifique quais meses apresentaram temperatura acima da
# média, informando também o nome do mês correspondente

# %%
meses = ["jan", "fev", "mar", "abr", "mai", "jun", "jul", "ago", "set", "out", "nov", "dez"]
temperatura = []

for mes in meses:
    temp = float(input(f"digite a temperatura do mes {mes}: "))
    temperatura.append(temp)
    
media = sum(temperatura)/len(meses)

print("a media é |", media)
print(f"###_Meses acima da media_###")

for n in range(len(meses)-1):
    if temperatura[n] > media:
        print(f"- Mes: {meses[n]} | temperatura:{temperatura[n]}")
# Out:
# a media é | 29.833333333333332
# os meses acima da media:
#  mes: jan | temperatura:40.0
#  mes: ago | temperatura:34.0
#  mes: set | temperatura:33.0
#  mes: out | temperatura:52.0
#  mes: nov | temperatura:62.0

# %% [markdown]
# 14. Uma lista de produtos disponíveis em um estoque foi previamente cadastrada.
# O sistema deve permitir que o usuário informe o nome de um produto e
# verificar se ele existe ou não nessa lista, exibindo uma mensagem adequada
# para cada situação.

# %%
produtos = ["Arroz","Feijao","oleo"]

for i in range(5):
    produto = input("Digite o nome do produto")


    if produto in produtos:
        print(f"Produto {produto} disponivel!")
    else:
        print(f"Produto {produto} não Disponivel.")
# Out:
# Produto Arroz disponivel!
# Produto oleo disponivel!
# Produto e não Disponivel.
# Produto  não Disponivel.
# Produto  não Disponivel.

# %% [markdown]
# 15. Um sistema acadêmico recebe notas de alunos de forma indefinida. A entrada
# deve ser encerrada quando o usuário digitar o valor zero. Após o
# encerramento, o programa deve informar a quantidade de notas registradas, a
# soma total e a média das notas.

# %% [markdown]
# 16. Durante uma votação interna, os participantes escolhem uma opção numerada
# de 1 a 5. O programa deve registrar os votos até que o valor zero seja
# informado. Ao final, o sistema deve mostrar quantas vezes cada opção foi
# escolhida, utilizando listas como contadores.

# %% [markdown]
# 17. Uma empresa deseja analisar os salários de seus funcionários. O programa
# deve ler o nome e o salário de cinco colaboradores, armazenar essas informações em listas e, ao final, informar qual funcionário possui o maior salário e qual é esse valor.

# %% [markdown]
# 18. Um sistema de simulação precisa gerar vinte números aleatórios entre 1 e 100.
# Esses valores devem ser armazenados em uma lista. Após isso, o programa deve identificar quais números são pares, quais são ímpares e informar a quantidade de cada grupo.

# %% [markdown]
# 19. Um sistema de cadastro territorial permite o registro de nomes de cidades até que o usuário digite a palavra “sairˮ. Ao final do cadastro, o programa deve exibir todas as cidades informadas e identificar qual delas possui o maior nome em quantidade de caracteres.

# %% [markdown]
# 20. Durante a validação de dados numéricos, um sistema precisa verificar se uma sequência de números está ordenada de forma crescente. Desenvolva um programa que, a partir de uma lista de números inteiros, determine se os valores estão ou não em ordem crescente.
